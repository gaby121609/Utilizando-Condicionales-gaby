# %% [markdown]
# Problema 1.
#
# En una celda pide lo siguiente
#
# 1. ¿Que fecha es hoy?
#
# 2. ¿En que fecha naciste?
#
# En otra celda determina si es tu cumpleaños o no

# %%
fecha= str(input("¿Que fecha es hoy?"))
nacimiento= str(input("¿Que dia naciste?"))
if fecha==nacimiento :
   print("¡¡¡Es tu cumpleaños!!!!",fecha)
else:
   print("No es tu cumpleaños")

# %% [markdown]
# Problema 2
#
# En una celda
#
# 1. Pide un numero
#
# 2. Pide otro numero
#
# Realiza operaciones para que tengan el mismo valor ejemplo:
#
# Valor= 1
#
# Valor=2
#
# 1*5  = 2+3

# %%
x= int(input("Ingresa el primer numero "))
z= int(input("Ingresa el segundo numero "))
if x*5==z+3 :
   print("Los resultados son iguales", "x*5==z+3")
else:
   print("Los resultados no son iguales")

# %% [markdown]
# Problema 3
#
# En una celda solicita:
#
# 1. Pide el codigo postal
#
# 2. Con ese codigo postal determina si esta dentro del rango de entrega
#
#  si su codigo esta entre 50000 y 50030 esta dentro del rango de entrega y puedes enviarle cosas, asi que publica un mensaje con ello, en caso contrario coloca un emoji triste y dile que no puedes entregarle nada

# %%
x= int(input("Ingresa tu codigo postal : "))
if x>=50000 and x<=50030:
   print("Te puedo enviar cosas 🥰")
else:
   print("No puedo entregarte nada 😭")
